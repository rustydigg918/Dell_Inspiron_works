# %%
import pandas as pd

# %%
drinks = pd.read_csv('http://bit.ly/31YGKsh')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %% [markdown]
# ## Looking at beer serving by continent

# %%
drinks.groupby(['continent']).beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# ## Filter the dataframe by africa

# %%
drinks[(drinks.continent == 'Africa')].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
drinks[(drinks.continent == 'Asia')].beer_servings.mean()
# Out:
# 37.04545454545455

# %%
drinks[(drinks.continent == 'Europe')].beer_servings.mean()
# Out:
# 193.77777777777777

# %%
drinks.groupby(['continent']).beer_servings.agg(['count', 'min', 'max', 'mean', 'median','std','cumsum'])
# Out:
#                count  min    max        mean  median        std  cumsum
# Africa          53.0  0.0  376.0   61.471698    32.0  80.557816     NaN
# Asia            44.0  0.0  247.0   37.045455    17.5  49.469725     NaN
# Europe          45.0  0.0  361.0  193.777778   219.0  99.631569     NaN
# North America   23.0  1.0  285.0  145.434783   143.0  79.621163     NaN
# Oceania         16.0  0.0  306.0   89.687500    52.5  96.641412     NaN
# ...              ...  ...    ...         ...     ...        ...     ...
# 188              NaN  NaN    NaN         NaN     NaN        NaN  2101.0
# 189              NaN  NaN    NaN         NaN     NaN        NaN  1624.0
# 190              NaN  NaN    NaN         NaN     NaN        NaN  1630.0
# 191              NaN  NaN    NaN         NaN     NaN        NaN  3194.0
# 192              NaN  NaN    NaN         NaN     NaN        NaN  3258.0
#
# [199 rows x 7 columns]

# %%
drinks.groupby('continent').agg(['count', 'min', 'max', 'mean', 'median','std','cumsum'])
# Out:
#               beer_servings                                                    \
#                       count  min    max        mean median        std  cumsum
# Africa                 53.0  0.0  376.0   61.471698   32.0  80.557816     NaN
# Asia                   44.0  0.0  247.0   37.045455   17.5  49.469725     NaN
# Europe                 45.0  0.0  361.0  193.777778  219.0  99.631569     NaN
# North America          23.0  1.0  285.0  145.434783  143.0  79.621163     NaN
# Oceania                16.0  0.0  306.0   89.687500   52.5  96.641412     NaN
# ...                     ...  ...    ...         ...    ...        ...     ...
# 188                     NaN  NaN    NaN         NaN    NaN        NaN  2101.0
# 189                     NaN  NaN    NaN         NaN    NaN        NaN  1624.0
# 190                     NaN  NaN    NaN         NaN    NaN        NaN  1630.0
# 191                     NaN  NaN    NaN         NaN    NaN        NaN  3194.0
# 192                     NaN  NaN    NaN         NaN    NaN        NaN  3258.0
#
#               spirit_servings               ... wine_servings             \
#                         count   min    max  ...        median        std
# Africa                   53.0   0.0  152.0  ...           2.0  38.846419
# Asia                     44.0   0.0  326.0  ...           1.0  21.667034
# Europe                   45.0   0.0  373.0  ...         128.0  97.421738
# North America            23.0  68.0  438.0  ...          11.0  28.266378
# Oceania                  16.0   0.0  254.0  ...           8.5  64.555790
# ...                       ...   ...    ...  ...           ...        ...
# 188                       NaN   NaN    NaN  ...           NaN        NaN
# 189                       NaN   NaN    NaN  ...           NaN        NaN
# 190                       NaN   NaN    NaN  ...           NaN        NaN
# 191                       NaN   NaN    NaN  ...           NaN        NaN
# 192                       NaN   NaN    NaN  ...           NaN        NaN
#
#                      total_litres_of_pure_alcohol                              \
#               cumsum                        count  min   max      mean median
# Africa           NaN                         53.0  0.0   9.1  3.007547   2.30
# Asia             NaN                         44.0  0.0  11.5  2.170455   1.20
# Europe           NaN                         45.0  0.0  14.4  8.617778  10.00
# North America    NaN                         23.0  2.2  11.9  5.995652   6.30
# Oceania          NaN                         16.0  0.0  10.4  3.381250   1.75
# ...              ...                          ...  ...   ...       ...    ...
# 188            749.0                          NaN  NaN   NaN       NaN    NaN
# 189            399.0                          NaN  NaN   NaN       NaN    NaN
# 190            399.0                          NaN  NaN   NaN       NaN    NaN
# 191            858.0                          NaN  NaN   NaN       NaN    NaN
# 192            862.0                          NaN  NaN   NaN       NaN    NaN
#
#
#                     std cumsum
# Africa         2.647557    NaN
# Asia           2.770239    NaN
# Europe         3.358455    NaN
# North America  2.409353    NaN
# Oceania        3.345688    NaN
# ...                 ...    ...
# 188                 NaN   75.7
# 189                 NaN   95.4
# 190                 NaN   95.5
# 191                 NaN  154.7
# 192                 NaN  159.4
#
# [199 rows x 28 columns]

# %%
# %matplotlib inline
drinks.groupby('continent').mean().plot(kind = 'bar')

# %% [markdown]
# ___
# ___
# ___
# ___

# %% [markdown]
# * Map
# * Apply
# * Apply Map

# %%
train = pd.read_csv('http://bit.ly/kaggletrain')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train['sex_num'] = train.Sex.map({'male':0, 'female':1})

# %%
train.loc[0:4, ['Sex','sex_num']]
# Out:
#       Sex  sex_num
# 0    male        0
# 1  female        1
# 2  female        1
# 3  female        1
# 4    male        0

# %%
# Out:
# Collecting pyod
#   Downloading pyod-0.7.7.1.tar.gz (87 kB)
# Collecting combo
#   Downloading combo-0.0.8.tar.gz (35 kB)
# Requirement already satisfied, skipping upgrade: joblib in c:\users\p raj\anaconda3\lib\site-packages (from pyod) (0.14.1)
# Requirement already satisfied, skipping upgrade: matplotlib in c:\users\p raj\anaconda3\lib\site-packages (from pyod) (3.1.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.13 in c:\users\p raj\anaconda3\lib\site-packages (from pyod) (1.18.1)
# Requirement already satisfied, skipping upgrade: numba>=0.35 in c:\users\p raj\anaconda3\lib\site-packages (from pyod) (0.48.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\p raj\anaconda3\lib\site-packages (from pyod) (1.4.1)
# Requirement already satisfied, skipping upgrade: scikit_learn>=0.19.1 in c:\users\p raj\anaconda3\lib\site-packages (from pyod) (0.22.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\p raj\anaconda3\lib\site-packages (from pyod) (1.14.0)
# Collecting suod
#   Downloading suod-0.0.2.tar.gz (2.1 MB)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\p raj\anaconda3\lib\site-packages (from matplotlib->pyod) (2.4.6)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\p raj\anaconda3\lib\site-packages (from matplotlib->pyod) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\p raj\anaconda3\lib\site-packages (from matplotlib->pyod) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\p raj\anaconda3\lib\site-packages (from matplotlib->pyod) (1.1.0)
# Requirement already satisfied, skipping upgrade: llvmlite<0.32.0,>=0.31.0dev0 in c:\users\p raj\anaconda3\lib\site-packages (from numba>=0.35->pyod) (0.31.0)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\p raj\anaconda3\lib\site-packages (from numba>=0.35->pyod) (45.2.0.post20200210)
# Building wheels for collected packages: pyod, combo, suod
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-0.7.7.1-py3-none-any.whl size=98966 sha256=28da1fb63371910212275f6e69bdb2341666c3be502b9fe05e24916fa775902c
#   Stored in directory: c:\users\p raj\appdata\local\pip\cache\wheels\eb\6f\c4\dfcc49a0e2ac35e3237beaf3e8fe133099b651df0058ffab72
#   Building wheel for combo (setup.py): started
#   Building wheel for combo (setup.py): finished with status 'done'
#   Created wheel for combo: filename=combo-0.0.8-py3-none-any.whl size=41514 sha256=a3358ec03be55bc0cd7677b3b305fd80f7987847830f2e3b251473f73bb507f1
#   Stored in directory: c:\users\p raj\appdata\local\pip\cache\wheels\fb\69\83\35e78de1adc72de0b88e170309c530d306632975a9545b84f9
#   Building wheel for suod (setup.py): started
#   Building wheel for suod (setup.py): finished with status 'done'
#   Created wheel for suod: filename=suod-0.0.2-py3-none-any.whl size=2163443 sha256=a92dc4cd809def5e934ff3991167b95e28e9ca6171b7c323a9bd168b738f0232
#   Stored in directory: c:\users\p raj\appdata\local\pip\cache\wheels\ec\52\d1\ddc3c9a8c5eb447102e66ea53becb956b5712f3be5bb26949a
# Successfully built pyod combo suod
# Installing collected packages: combo, suod, pyod
# Successfully installed combo-0.0.8 pyod-0.7.7.1 suod-0.0.2
